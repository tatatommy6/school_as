# %% [markdown]
# # [아나콘다 설치하기]
#
# - https://www.anaconda.com/download/success

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 구글 드라이브에서 다운로드
# Colab의 /content/ 폴더에 다운로드됨
# !gdown 1jH0ZnFaLduDCdmdQLfsTtC0YHaZb4IRS

# %% [markdown]
# # [주피터노트북 실행하기]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # [라이브러리 설치]
#
# - RobokitRS
# - RoboCam

# %% [markdown]
# - 주피터 노트북 실행 후 터미널 열고 설치하기

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### [RobokitRS]
#
# - 설치 : pip install RobokitRS
# - 업그레이드 : pip install --upgrade RobokitRS
# - 삭제 : pip uninstall RobokitRS

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### [RoboCam]
# - 설치 : pip install RoboCam
# - 업그레이드 : pip install --upgrade RoboCam
# - 삭제 : pip uninstall RoboCam

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # [설치된 라이브러리 확인]
# - pip list
# - RobokitRS, RoboCam 있는지 확인하기

# %%
pip list
